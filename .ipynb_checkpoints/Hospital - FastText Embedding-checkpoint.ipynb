# %% [markdown]
# # Record Embedding

# %%
import pandas as pd
import numpy as np
import os
import calendar
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Embedding using fastText
# Details here: https://fasttext.cc/

# %%
import warnings
warnings.filterwarnings('ignore')

import gensim
from gensim.models import FastText

# %% [markdown]
# Convert each tuple into a row

# %%
#hospital dataset

#1. load hospital dataset and turthvalue.csv; mark error for unmatched values and cleanup using FastText; fill empty cells with word2vec
#finding errors and outliers -> discover FDs and try marking errors? or word2vec most_similar of val and if row does not contain the cell values??!

df_hospital = pd.read_csv('dirty_data_transformed.csv', dtype=object)
df_truth = pd.read_csv('truthvalue.csv', dtype=object)



provider = df_truth['ProviderNumber'].tolist()
hospital = df_truth['HospitalName'].tolist()
address = df_truth['Address1'].tolist()
city = df_truth['City'].tolist()
state = df_truth['State'].tolist()
zipcode = df_truth['ZipCode'].tolist()
county = df_truth['CountyName'].tolist()
phone = df_truth['PhoneNumber'].tolist()
hospType = df_truth['HospitalType'].tolist()
owner = df_truth['HospitalOwner'].tolist()
service = df_truth['EmergencyService'].tolist()
condition = df_truth['Condition'].tolist()
code = df_truth['MeasureCode'].tolist()
name = df_truth['MeasureName'].tolist()
score = df_truth['Score'].tolist()
sample = df_truth['Sample'].tolist()
stateavg = df_truth['Stateavg'].tolist()

combined_hosp = list(zip(provider, hospital, address, city, state, zipcode, county, phone, hospType, owner, service, condition, code, name, score, sample, stateavg))

# %%
len(df_truth)
# Out:
# 1000

# %%
len(combined_hosp[1])
# Out:
# 17

# %%
#hospital dirty dataset; maintain dirty dataset separately
provider = df_hospital['ProviderNumber'].tolist()
hospital = df_hospital['HospitalName'].tolist()
address = df_hospital['Address1'].tolist()
city = df_hospital['City'].tolist()
state = df_hospital['State'].tolist()
zipcode = df_hospital['ZipCode'].tolist()
county = df_hospital['CountyName'].tolist()
phone = df_hospital['PhoneNumber'].tolist()
hospType = df_hospital['HospitalType'].tolist()
owner = df_hospital['HospitalOwner'].tolist()
service = df_hospital['EmergencyService'].tolist()
condition = df_hospital['Condition'].tolist()
code = df_hospital['MeasureCode'].tolist()
name = df_hospital['MeasureName'].tolist()
score = df_hospital['Score'].tolist()
sample = df_hospital['Sample'].tolist()
stateavg = df_hospital['Stateavg'].tolist()

combined_dirty = list(zip(provider, hospital, address, city, state, zipcode, county, phone, hospType, owner, service, condition, code, name, score, sample, stateavg))
len(combined_dirty)
# Out:
# 1000

# %%
#Calculating error or dirty cells
dirty_list = []
truth_list = []
for i in range(len(combined_dirty)):
    for j in range(len(combined_dirty[0])):
        if combined_dirty[i][j] != combined_hosp[i][j]:
            dirty_list.append(combined_dirty[i][j])
            truth_list.append(combined_hosp[i][j])

# %%
len(combined_dirty)
# Out:
# 1000

# %%
#training the model with truth data.
model_hosp = FastText(combined_hosp, min_count=1, workers=8, iter=100)

# %%
#module to predict the top value by the model.Some values are not broken into tokens.
#Values with keyerrors are stored in excluded_list

excluded_list = []
result = []
for i in range(len(dirty_list)):
    if isinstance(dirty_list[i], str):
        try:
            result.append((model_hosp.most_similar(dirty_list[i])[0][0],dirty_list[i],truth_list[i]))
        except KeyError:
            excluded_list.append(dirty_list[i])
            #print(dirty_list[i])
            pass

# %%
print (len(excluded_list))
print (len(result))
print (len(excluded_list) + len(result))
print (len(dirty_list))
excluded_list[0]
# Out:
# 51
# 543
# 594
# 594
# 'Yxs'

# %%
#identify the true positives and false positives. Store them in the seperate list for further analysis.
true_pos = 0
false_pos = 0
correctly_predicted = []
falsely_predicted = []
for i in range(len(result)):
    if result[i][0] == result[i][2]:
        true_pos = true_pos + 1
        correctly_predicted.append(result[i])
    else:
        false_pos = false_pos + 1
        falsely_predicted.append(result[i])

# %%
print(len(result))
print(len(correctly_predicted))
print(len(falsely_predicted))
# Out:
# 543
# 369
# 174

# %%
correctly_predicted[8]

for i in falsely_predicted:
    print (i)
# Out:
# ('SHEFFIELD', '1xx19', '10019')
# ('588 patients', '3x patients', '37 patients')
# ('BOAZ', 'x5957', '35957')
# ('BOAZ', 'x0005', '10005')
# ('AL_PN-6', 'AL_PN-xB', 'AL_PN-3B')
# ('10009', '1000x', '10006')
# ('2059344011', '619 paxienxs', '619 patients')
# ('HF-4', 'HFx1', 'HF-1')
# ('AK_AMI-2', 'AxI-2', 'AMI-2')
# ('0%', 'x00%', '100%')
# ('1016 patients', '21 pxtients', '21 patients')
# ('36078', '360x9', '36049')
# ('MORGAN', '3x640', '35640')
# ('MORGAN', '3x640', '35640')
# ('HARTSELLE', '201 PINE SxREEx NORxHWESx', '201 PINE STREET NORTHWEST')
# ('588 patients', 'xx patients', '11 patients')
# ('48 patients', '6xpatients', '6 patients')
# ('HF-4', 'HF-x', 'HF-2')
# ('65%', 'x5%', '95%')
# ('AK_SCIP-INF-2', 'AL_SxIP-INF-2', 'AL_SCIP-INF-2')
# ('Voluntary non-profit - Other', 'Voluntary non-profit - Private', '10011')
# ('35653', 'Yes', "ST VINCENT'S EAST")
# ('Heart Attack Patients Given ACE Inhibitor or ARB for Left Ventricular Systolic Dysfunction (LVSD)', 'Surgical Infection Prevention', '50 MEDICAL PARK EAST DRIVE')
# ('0%', '60%', 'BIRMINGHAM')
# ('227 patients', '127 patients', 'AL')
# ('AL_SCIP-INF-3', 'AL_SCIP-INF-4', '35235')
# ('10018', '10011', 'JEFFERSON')
# ('810 ST VINCENTS DRIVE', "ST VINCENT'S EAST", '2058383122')
# ("ST VINCENT'S EAST", '50 MEDICAL PARK EAST DRIVE', 'Acute Care Hospitals')
# ('50%', 'Empty', 'Voluntary non-profit - Private')
# ('50%', 'Empty', 'Yes')
# ('35233', 'BIRMINGHAM', 'Surgical Infection Prevention')
# ('AL_AMI-3', 'AL', 'SCIP-INF-4')
# ('35233', '35235', 'all heart surgery patients whose blood sugar (blood glucose) is kept under good control in the days right after surgery')
# ('BIRMINGHAM', 'JEFFERSON', '60%')
# ('35235', '2058383122', '127 patients')
# ('35957', 'Acute Care Hospitals', 'AL_SCIP-INF-4')
# ('35957', '359x8', '35968')
# ('1062 patients', '82 patientx', '82 patients')
# ('AK_AMI-1', 'Ax_AMI-1', 'AL_AMI-1')
# ('AMI-5', 'xL_xMI-5', 'AL_AMI-5')
# ('CLARKE', '1xx15', '10015')
# ('93%', 'x6%', '96%')
# ('AK_SCIP-INF-3', 'SCxP-xNF-3', 'SCIP-INF-3')
# ('36116', '1xx16', '10016')
# ('SHELBY', 'x5007', '35007')
# ('10085', '100x8', '10038')
# ('35 patients', '29 xatients', '29 patients')
# ('36801', '36x01', '36201')
# ('AL_PN-7', 'AL_PNx2', 'AL_PN-2')
# ('0%', 'x00%', '100%')
# ('3343762205', 'x6x05', '36305')
# ('AL_SCIP-VTE-1', 'AL_SCIPxVTEx2', 'AL_SCIP-VTE-2')
# ('AMI-3', 'AMIx2', 'AMI-2')
# ('588 patients', '1x patients', '10 patients')
# ('10085', '100x6', '10086')
# ('WINFIELD', '3xx94', '35594')
# ('AK_PN-7', 'ALxPN-7', 'AL_PN-7')
# ('AK_SCIP-INF-2', 'AL_SxIP-INF-2', 'AL_SCIP-INF-2')
# ('WINFIELD', '3xx94', '35594')
# ('65%', 'x5%', '95%')
# ('2563321611', '25x47x7xx0', '2514717110')
# ('2563321611', '25x47x7xx0', '2514717110')
# ('2563321611', '25x47x7xx0', '2514717110')
# ('PN-5C', 'PN-xB', 'PN-3B')
# ('AK_HF-1', 'Hx-1', 'HF-1')
# ('4%', 'x4%', '94%')
# ('PO BOX 287', '3x0x7', '36067')
# ('AK', 'x0x08', '10108')
# ('SCIP-INF-6', 'SCIPxINFx1', 'SCIP-INF-1')
# ('123 patients', '4 xatients', '4 patients')
# ('57%', 'x7%', '97%')
# ('Pneumonia Patients Whose Initial Emergency Room Blood Culture Was Performed Prior To The Administration Of The First Hospital Dose Of Antibiotics', '3x1x0', '35150')
# ('1001 patients', '521 patiexts', '521 patients')
# ('588 patients', 'x patients', '0 patients')
# ('AK_SCIP-VTE-1', 'SxIP-VTE-1', 'SCIP-VTE-1')
# ('AK_PN-2', 'Ax_PN-2', 'AL_PN-2')
# ('COOSA VALLEY MEDICAL CENTER', 'DALE MEDICAL CENTER', '10021')
# ('RUSSELLVILLE HOSPITAL', '126 HOSPITAL AVE', 'DALE MEDICAL CENTER')
# ('50%', 'Empty', '126 HOSPITAL AVE')
# ('AL_AMI-3', 'AL', 'OZARK')
# ('3347742601', '36360', 'AL')
# ('OZARK', 'DALE', '36360')
# ('36360', '3347742601', 'DALE')
# ('35957', 'Acute Care Hospitals', '3347742601')
# ('Government - State', 'Government - Hospital District or Authority', 'Acute Care Hospitals')
# ('35653', 'Yes', 'Government - Hospital District or Authority')
# ('Heart Attack Patients Given ACE Inhibitor or ARB for Left Ventricular Systolic Dysfunction (LVSD)', 'Surgical Infection Prevention', 'Yes')
# ('SCIP-INF-1', 'SCIP-INF-2', 'Surgical Infection Prevention')
# ('surgery patients who were given an antibiotic at the right time (within one hour before surgery) to help prevent infection', 'surgery patients who were given the  right kind  of antibiotic to help prevent infection', 'SCIP-INF-2')
# ('93%', '96%', 'surgery patients who were given the  right kind  of antibiotic to help prevent infection')
# ('852 patients', '52 patients', '96%')
# ('AL_SCIP-INF-1', 'AL_SCIP-INF-2', '52 patients')
# ('10029', '10021', 'AL_SCIP-INF-2')
# ('35660', 'x6x60', '36360')
# ('AMI-3', 'AMI-x', 'AMI-5')
# ('CHEROKEE', 'x5960', '35960')
# ('36 patients', '44 paxienxs', '44 patients')
# ('254 patients', '25x patients', '257 patients')
# ('Pneumonia Patients Whose Initial Emergency Room Blood Culture Was Performed Prior To The Administration Of The First Hospital Dose Of Antibiotics', '3x10x', '36106')
# ('588 patients', 'x patients', '0 patients')
# ('36106', '1xx24', '10024')
# ('AK_AMI-2', 'xL_xMI-2', 'AL_AMI-2')
# ('AK_PN-5C', 'Px-5C', 'PN-5C')
# ('205 patients', '50 pxtients', '50 patients')
# ('ELBA', 'x0027', '10027')
# ('AL_AMI-4', 'AL_AMIx8A', 'AL_AMI-8A')
# ('2000 PEPPERELL PARKWAY', 'x0029', '10029')
# ('36278', 'xEE', 'LEE')
# ('2000 PEPPERELL PARKWAY', '1xx29', '10029')
# ('WEDOWEE', '1xx32', '10032')
# ('AMI-7A', 'ALxAMI-7A', 'AL_AMI-7A')
# ('HF-4', 'HFx1', 'HF-1')
# ('WEDOWEE', 'WEDOWEE HOSxITAL', 'WEDOWEE HOSPITAL')
# ('WEDOWEE', '1xx32', '10032')
# ('AK_HF-1', 'xF-1', 'HF-1')
# ('AK_PN-3B', 'ALxPN-3B', 'AL_PN-3B')
# ('AMI-3', 'AMIx1', 'AMI-1')
# ('AMI-7A', 'AMx-4', 'AMI-4')
# ('10085', '100x4', '10034')
# ('57%', 'x7%', '67%')
# ('10085', '100x5', '10035')
# ('35235', '1xx35', '10035')
# ('HF-4', 'Px-4', 'PN-4')
# ('AK_SCIP-CARD-2', 'Hx-2', 'HF-2')
# ('35957', 'Acute Care Hospitals', '10036')
# ('ETOWAH', 'Proprietary', 'ANDALUSIA REGIONAL HOSPITAL')
# ('80%', 'No', '849 SOUTH THREE NOTCH STREET')
# ('Heart Failure Patients Given Smoking Cessation Advice/Counseling', 'Pneumonia Patients Given Smoking Cessation Advice/Counseling', 'ANDALUSIA')
# ('10085', '100%', 'AL')
# ('243 patients', '43 patients', '36420')
# ('AL_PN-2', 'AL_PN-4', 'COVINGTON')
# ('10032', '10036', '3342228466')
# ('ALASKA REGIONAL HOSPITAL', 'ANDALUSIA REGIONAL HOSPITAL', 'Acute Care Hospitals')
# ('619 SOUTH 19TH STREET', '849 SOUTH THREE NOTCH STREET', 'Proprietary')
# ('50%', 'Empty', 'No')
# ('50%', 'Empty', 'Pneumonia')
# ('36420', 'ANDALUSIA', 'PN-4')
# ('AL_AMI-3', 'AL', 'Pneumonia Patients Given Smoking Cessation Advice/Counseling')
# ('COVINGTON', '36420', '100%')
# ('36467', 'COVINGTON', '43 patients')
# ('36420', '3342228466', 'AL_PN-4')
# ('2054877736', '1xx36', '10036')
# ('AL_SCIP-INF-3', 'AL_SCIPxINFx2', 'AL_SCIP-INF-2')
# ('63%', 'x3%', '93%')
# ('AK_HF-1', 'xAx-1', 'CAC-1')
# ('Children and their Caregivers Who Received a Home Management Plan of Care Document While Hospitalized for Asthma', '193 paxienxs', '193 patients')
# ('101 SIVLEY RD', 'HUNTSVxLLE HOSPxTAL', 'HUNTSVILLE HOSPITAL')
# ('10032', '1003x', '10039')
# ('AL_HF-1', 'AL_HF-x', 'AL_HF-4')
# ('PN-6', 'PN-x', 'PN-2')
# ('101 SIVLEY RD', '1xx39', '10039')
# ('10085', '100x9', '10039')
# ('AK_SCIP-INF-2', 'xL_SCIP-INF-2', 'AL_SCIP-INF-2')
# ('ETOWAH', 'x590x', '35903')
# ('AK_AMI-1', 'xL_xMI-1', 'AL_AMI-1')
# ('AL_PN-7', 'AL_PNx6', 'AL_PN-6')
# ('MARION', 'HAMILxON', 'HAMILTON')
# ('2059397000', 'x059x16x00', '2059216200')
# ('MARION', '1xx44', '10044')
# ('805 FRIENDSHIP ROAD', '80x', '80%')
# ('HF-4', 'Px-4', 'PN-4')
# ('101 patients', '121 patiexts', '121 patients')
# ('1010 LAY DAM ROAD', '1xx45', '10045')
# ('1010 LAY DAM ROAD', 'x0045', '10045')
# ('65%', 'x5%', '85%')
# ('GADSDEN', '600 SOUxH xHIRD SxREEx', '600 SOUTH THIRD STREET')
# ('AK_PN-6', 'ALxPN-6', 'AL_PN-6')
# ('35903', '3590x', '35901')
# ('AMI-3', 'AMIx1', 'AMI-1')
# ('GEORGIANA', '1xx47', '10047')
# ('GEORGIANA', '515 MIRANDA Sx', '515 MIRANDA ST')
# ('10046', '1004x', '10049')
# ('ENTERPRISE', 'MEDIxAL xENTER ENTERPRISE', 'MEDICAL CENTER ENTERPRISE')

# %%
for i in correctly_predicted:
    print (i)
# Out:
# ('surgery patients who were taking heart drugs called beta blockers before coming to the hospital who were kept on the beta blockers during the period just before and after their surgery', 'surgery patients who were taking heart drugs caxxed beta bxockers before coming to the hospitax who were kept on the beta bxockers during the period just before and after their surgery', 'surgery patients who were taking heart drugs called beta blockers before coming to the hospital who were kept on the beta blockers during the period just before and after their surgery')
# ('BIRMINGHAM', 'BIRMINGHxM', 'BIRMINGHAM')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('BIRMINGHAM', 'BIRMINGxAM', 'BIRMINGHAM')
# ('SHEFFIELD', 'SHEFFxELD', 'SHEFFIELD')
# ('Acute Care Hospitals', 'Acuxe Care Hospixals', 'Acute Care Hospitals')
# ('Heart Attack', 'Heart Attaxk', 'Heart Attack')
# ('Government - Hospital District or Authority', 'Government - Hospxtal Dxstrxct or Authorxty', 'Government - Hospital District or Authority')
# ('Heart Attack', 'Hearx Axxack', 'Heart Attack')
# ('3347938701', '334793870x', '3347938701')
# ('SOUTHEAST ALABAMA MEDICAL CENTER', 'SOUTHEAST ALABAMA MEDxCAL CENTER', 'SOUTHEAST ALABAMA MEDICAL CENTER')
# ('Government - Hospital District or Authority', 'Government - Hospital xistrict or Authority', 'Government - Hospital District or Authority')
# ('Government - Hospital District or Authority', 'Governmenx - Hospixal Disxricx or Auxhorixy', 'Government - Hospital District or Authority')
# ('3347938701', 'xx479x8701', '3347938701')
# ('Acute Care Hospitals', 'Acxte Care Hospitals', 'Acute Care Hospitals')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('Government - Hospital District or Authority', 'Gxvernment - Hxspital District xr Authxrity', 'Government - Hospital District or Authority')
# ('Yes', 'Yex', 'Yes')
# ('BOAZ', 'BOxZ', 'BOAZ')
# ('2505 U S HIGHWAY 431 NORTH', '2505xUxSxHIGHWAYx431xNORTH', '2505 U S HIGHWAY 431 NORTH')
# ('2565938310', '2x6x938310', '2565938310')
# ('2565938310', '2x6x938310', '2565938310')
# ('35957', '3595x', '35957')
# ('2565938310', '2565x38310', '2565938310')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('MARSHALL', 'MxRSHxLL', 'MARSHALL')
# ('AL_AMI-1', 'AL_AMx-1', 'AL_AMI-1')
# ('35631', '3563x', '35631')
# ('LAUDERDALE', 'LAUDxRDALx', 'LAUDERDALE')
# ('Heart Attack', 'Hearx Axxack', 'Heart Attack')
# ('LAUDERDALE', 'LAUDExDALE', 'LAUDERDALE')
# ('FLORENCE', 'FxORENCE', 'FLORENCE')
# ('FLORENCE', 'FLORxNCx', 'FLORENCE')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('FLORENCE', 'FLxRENCE', 'FLORENCE')
# ('35631', '3563x', '35631')
# ('702 N MAIN ST', '702xNxMAINxST', '702 N MAIN ST')
# ('Heart Attack Patients Given Aspirin at Arrival', 'xeart Attack Patients Given Aspirin at Arrival', 'Heart Attack Patients Given Aspirin at Arrival')
# ('AMI-4', 'AxI-4', 'AMI-4')
# ('Acute Care Hospitals', 'Acute Care Hosxitals', 'Acute Care Hospitals')
# ('3344933541', '3344x33541', '3344933541')
# ('702 N MAIN ST', '702 x MAIx ST', '702 N MAIN ST')
# ('PN-5C', 'PNx5C', 'PN-5C')
# ('surgery patients who were taking heart drugs called beta blockers before coming to the hospital who were kept on the beta blockers during the period just before and after their surgery', 'surgery patiexts who were takixg heart drugs called beta blockers before comixg to the hospital who were kept ox the beta blockers durixg the period just before axd after their surgery', 'surgery patients who were taking heart drugs called beta blockers before coming to the hospital who were kept on the beta blockers during the period just before and after their surgery')
# ('Voluntary non-profit - Private', 'Volunxary non-profix - Privaxe', 'Voluntary non-profit - Private')
# ('0 patients', '0 patixnts', '0 patients')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('Heart Attack Patients Given Aspirin at Arrival', 'Heart Attack Patients Given Aspirin at Arrivax', 'Heart Attack Patients Given Aspirin at Arrival')
# ('Heart Failure', 'Heaxt Failuxe', 'Heart Failure')
# ('CRENSHAW COMMUNITY HOSPITAL', 'CRENSHAW CxMMUNITY HxSPITAL', 'CRENSHAW COMMUNITY HOSPITAL')
# ('CRENSHAW', 'CRxNSHAW', 'CRENSHAW')
# ('36049', '36x49', '36049')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('Heart Attack Patients Given Aspirin at Discharge', 'Heart Attaxk Patients Given Aspirin at Disxharge', 'Heart Attack Patients Given Aspirin at Discharge')
# ('Proprietary', 'Pxopxietaxy', 'Proprietary')
# ('Proprietary', 'Proxrietary', 'Proprietary')
# ('Proprietary', 'xroprietary', 'Proprietary')
# ('57%', 'x7%', '57%')
# ('Proprietary', 'Pxopxietaxy', 'Proprietary')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('MARSHALL MEDICAL CENTER NORTH', 'MARSHALL MEDICAL CENxER NORxH', 'MARSHALL MEDICAL CENTER NORTH')
# ('8000 ALABAMA HIGHWAY 69', '8000 ALABAMA xIGxWAY 69', '8000 ALABAMA HIGHWAY 69')
# ('GUNTERSVILLE', 'GUNTxRSVILLx', 'GUNTERSVILLE')
# ('95%', '95x', '95%')
# ('SCIP-INF-4', 'SCIP-INx-4', 'SCIP-INF-4')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('AL_SCIP-VTE-2', 'AL_SCIx-VTE-2', 'AL_SCIP-VTE-2')
# ('Acute Care Hospitals', 'Acute Care Hosxitals', 'Acute Care Hospitals')
# ('Heart Attack', 'Heaxt Attack', 'Heart Attack')
# ('BIRMINGHAM', 'BIRMIxGHAM', 'BIRMINGHAM')
# ('Pneumonia Patients Assessed and Given Influenza Vaccination', 'PneumoniaxPatientsxAssessedxandxGivenxInfluenzaxVaccination', 'Pneumonia Patients Assessed and Given Influenza Vaccination')
# ('BIRMINGHAM', 'BxRMxNGHAM', 'BIRMINGHAM')
# ('Acute Care Hospitals', 'Acutx Carx Hospitals', 'Acute Care Hospitals')
# ('JEFFERSON', 'JEFFERSxN', 'JEFFERSON')
# ('Voluntary non-profit - Private', 'Volunxary non-profix - Privaxe', 'Voluntary non-profit - Private')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('2058383122', '2058x8x122', '2058383122')
# ('Voluntary non-profit - Private', 'Voluntary nonxprofit x Private', 'Voluntary non-profit - Private')
# ('Heart Attack Patients Given Aspirin at Arrival', 'HeartxAttackxPatientsxGivenxAspirinxatxArrival', 'Heart Attack Patients Given Aspirin at Arrival')
# ('DE KALB', 'Dx KALB', 'DE KALB')
# ('Voluntary non-profit - Church', 'Voluntaryxnon-profitx-xChurch', 'Voluntary non-profit - Church')
# ('DE KALB', 'xE KALB', 'DE KALB')
# ('1 patients', '1 patiexts', '1 patients')
# ('Heart Attack', 'Hexrt Attxck', 'Heart Attack')
# ('DE KALB', 'Dx KALB', 'DE KALB')
# ('FORT PAYNE', 'FORT PAYxE', 'FORT PAYNE')
# ('2568453150', '2568453x50', '2568453150')
# ('Heart Failure', 'Heart Faxlure', 'Heart Failure')
# ('Surgical Infection Prevention', 'Suxgical Infection Pxevention', 'Surgical Infection Prevention')
# ('DE KALB', 'xE KALB', 'DE KALB')
# ('Voluntary non-profit - Church', 'Voxuntary non-profit - Church', 'Voluntary non-profit - Church')
# ('Surgical Infection Prevention', 'Surgxcal Infectxon Preventxon', 'Surgical Infection Prevention')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('DEKALB REGIONAL MEDICAL CENTER', 'DExALB REGIONAL MEDICAL CENTER', 'DEKALB REGIONAL MEDICAL CENTER')
# ('3346366221', 'xx46x66221', '3346366221')
# ('Government - Federal', 'Governxent - Federal', 'Government - Federal')
# ('CLARKE', 'xLARKE', 'CLARKE')
# ('89%', '89x', '89%')
# ('Pneumonia', 'xneumonia', 'Pneumonia')
# ('Pneumonia Patients Whose Initial Emergency Room Blood Culture Was Performed Prior To The Administration Of The First Hospital Dose Of Antibiotics', 'Pneumonxa Patxents Whose Inxtxal Emergency Room Blood Culture Was Performed Prxor To The Admxnxstratxon Of The Fxrst Hospxtal Dose Of Antxbxotxcs', 'Pneumonia Patients Whose Initial Emergency Room Blood Culture Was Performed Prior To The Administration Of The First Hospital Dose Of Antibiotics')
# ('33700 HIGHWAY 43', '33700 HxGHWAY 43', '33700 HIGHWAY 43')
# ('3346366221', '334x3xx221', '3346366221')
# ('33700 HIGHWAY 43', '33700 HIGHWAY x3', '33700 HIGHWAY 43')
# ('Acute Care Hospitals', 'Acuxe Care Hospixals', 'Acute Care Hospitals')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('36784', 'x6784', '36784')
# ('AL_AMI-1', 'AL_AxI-1', 'AL_AMI-1')
# ('Heart Failure', 'xeart Failure', 'Heart Failure')
# ('Acute Care Hospitals', 'AcutexCarexHospitals', 'Acute Care Hospitals')
# ('Pneumonia Patients Whose Initial Emergency Room Blood Culture Was Performed Prior To The Administration Of The First Hospital Dose Of Antibiotics', 'Pnxumonia Patixnts Whosx Initial Emxrgxncy Room Blood Culturx Was Pxrformxd Prior To Thx Administration Of Thx First Hospital Dosx Of Antibiotics', 'Pneumonia Patients Whose Initial Emergency Room Blood Culture Was Performed Prior To The Administration Of The First Hospital Dose Of Antibiotics')
# ('35007', '3x007', '35007')
# ('all heart surgery patients whose blood sugar (blood glucose) is kept under good control in the days right after surgery', 'all heart surgerx patients whose blood sugar (blood glucose) is kept under good control in the daxs right after surgerx', 'all heart surgery patients whose blood sugar (blood glucose) is kept under good control in the days right after surgery')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('Acute Care Hospitals', 'Acuxe Care Hospixals', 'Acute Care Hospitals')
# ('1720 UNIVERSITY BLVD', '1720 UNIVxRSITY BLVD', '1720 UNIVERSITY BLVD')
# ('ANNISTON', 'AxxISTOx', 'ANNISTON')
# ('CALHOUN', 'CALHOxN', 'CALHOUN')
# ('Proprietary', 'Prxprietary', 'Proprietary')
# ('301 EAST 18TH ST', '301xEASTx18THxST', '301 EAST 18TH ST')
# ('Yes', 'xes', 'Yes')
# ('2562358900', '256235x900', '2562358900')
# ('CALHOUN', 'CAxHOUN', 'CALHOUN')
# ('Yes', 'Yex', 'Yes')
# ('36305', '3x305', '36305')
# ('Proprietary', 'Proxrietary', 'Proprietary')
# ('Yes', 'Yex', 'Yes')
# ('4370 WEST MAIN STREET', '4370xWESTxMAINxSTREET', '4370 WEST MAIN STREET')
# ('FLOWERS HOSPITAL', 'FLOxERS HOSPITAL', 'FLOWERS HOSPITAL')
# ('3347935000', 'xx479x5000', '3347935000')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('HOUSTON', 'HOUSxON', 'HOUSTON')
# ('surgery patients whose doctors ordered treatments to prevent blood clots after certain types of surgeries', 'surgery pxtients whose doctors ordered trextments to prevent blood clots xfter certxin types of surgeries', 'surgery patients whose doctors ordered treatments to prevent blood clots after certain types of surgeries')
# ('810 ST VINCENTS DRIVE', '810 ST VxNCENTS DRxVE', '810 ST VINCENTS DRIVE')
# ('Proprietary', 'Prxprietary', 'Proprietary')
# ('1530 U S HIGHWAY 43', '1530xUxSxHIGHWAYx43', '1530 U S HIGHWAY 43')
# ('Pneumonia', 'Pnxumonia', 'Pneumonia')
# ('WINFIELD', 'WINFIELx', 'WINFIELD')
# ('Pneumonia', 'Pnexmonia', 'Pneumonia')
# ('Yes', 'Yex', 'Yes')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('Heart Attack Patients Given Aspirin at Discharge', 'Heaxt Attack Patients Given Aspixin at Dischaxge', 'Heart Attack Patients Given Aspirin at Discharge')
# ('UNIV OF SOUTH ALABAMA MEDICAL CENTER', 'UNIV Ox SOUTH ALABAMA MEDICAL CENTER', 'UNIV OF SOUTH ALABAMA MEDICAL CENTER')
# ('UNIV OF SOUTH ALABAMA MEDICAL CENTER', 'xNIV OF SOxTH ALABAMA MEDICAL CENTER', 'UNIV OF SOUTH ALABAMA MEDICAL CENTER')
# ('Heart Failure', 'Hxart Failurx', 'Heart Failure')
# ('AL_HF-2', 'AL_Hx-2', 'AL_HF-2')
# ('Heart Failure Patients Given Smoking Cessation Advice/Counseling', 'Heart xailure Patients Given Smoking Cessation Advice/Counseling', 'Heart Failure Patients Given Smoking Cessation Advice/Counseling')
# ('124 S MEMORIAL DR', '124xSxMEMORIALxDR', '124 S MEMORIAL DR')
# ('3343614267', '33x361x267', '3343614267')
# ('Heart Failure', 'Hxart Failurx', 'Heart Failure')
# ('124 S MEMORIAL DR', '124 S MxMORIAL DR', '124 S MEMORIAL DR')
# ('Acute Care Hospitals', 'Acute Care Hosxitals', 'Acute Care Hospitals')
# ('Acute Care Hospitals', 'Acuxe Care Hospixals', 'Acute Care Hospitals')
# ('125 patients', '125 patixnts', '125 patients')
# ('315 W HICKORY ST', '315 W HICKxRY ST', '315 W HICKORY ST')
# ('TALLADEGA', 'TALLAxEGA', 'TALLADEGA')
# ('35150', 'x5150', '35150')
# ('315 W HICKORY ST', '315xWxHICKORYxST', '315 W HICKORY ST')
# ('Heart Failure Patients Given ACE Inhibitor or ARB for Left Ventricular Systolic Dysfunction (LVSD)', 'Heart Faxlure Patxents Gxven ACE Inhxbxtor or ARB for Left Ventrxcular Systolxc Dysfunctxon (LVSD)', 'Heart Failure Patients Given ACE Inhibitor or ARB for Left Ventricular Systolic Dysfunction (LVSD)')
# ('ANCHORAGE', 'ANCHORAxE', 'ANCHORAGE')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgeryxpatientsxneedingxhairxremovedxfromxthexsurgicalxareaxbeforexsurgery& xwhoxhadxhairxremovedxusingxaxsaferxmethodx(electricxclippersxorxhairxremovalxcreamx�Cxnotxaxrazor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('ALASKA REGIONAL HOSPITAL', 'xLxSKx REGIONxL HOSPITxL', 'ALASKA REGIONAL HOSPITAL')
# ('Proprietary', 'Proxrietary', 'Proprietary')
# ('PO BOX 287', 'POxBOXx287', 'PO BOX 287')
# ('Acute Care Hospitals', 'Acute Care Hospitaxs', 'Acute Care Hospitals')
# ('JEFFERSON', 'JxFFxRSON', 'JEFFERSON')
# ('Government - Hospital District or Authority', 'Gxvernment - Hxspital District xr Authxrity', 'Government - Hospital District or Authority')
# ('JEFFERSON', 'xEFFERSON', 'JEFFERSON')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('JEFFERSON', 'JExxERSON', 'JEFFERSON')
# ('Heart Attack', 'Hexrt Attxck', 'Heart Attack')
# ('3347742601', '334774x601', '3347742601')
# ('126 HOSPITAL AVE', '126xHOSPITALxAVE', '126 HOSPITAL AVE')
# ('Heart Failure Patients Given Discharge Instructions', 'Heaxt Failuxe Patients Given Dischaxge Instxuctions', 'Heart Failure Patients Given Discharge Instructions')
# ('OZARK', 'OZARx', 'OZARK')
# ('62 patients', '62 patientx', '62 patients')
# ('126 HOSPITAL AVE', '1x6 HOSPITAL AVE', '126 HOSPITAL AVE')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('Acute Care Hospitals', 'Acute Caxe Hospitals', 'Acute Care Hospitals')
# ('Acute Care Hospitals', 'Acute Care Hxspitals', 'Acute Care Hospitals')
# ('Voluntary non-profit - Private', 'Voluntaryxnon-profitx-xPrivate', 'Voluntary non-profit - Private')
# ('Heart Attack Patients Given ACE Inhibitor or ARB for Left Ventricular Systolic Dysfunction (LVSD)', 'Hxart Attack Patixnts Givxn ACE Inhibitor or ARB for Lxft Vxntricular Systolic Dysfunction (LVSD)', 'Heart Attack Patients Given ACE Inhibitor or ARB for Left Ventricular Systolic Dysfunction (LVSD)')
# ('0 patients', '0 patxents', '0 patients')
# ('Acute Care Hospitals', 'Acutx Carx Hospitals', 'Acute Care Hospitals')
# ('CHEROKEE', 'CHxROKxx', 'CHEROKEE')
# ('Pneumonia', 'Pneumonix', 'Pneumonia')
# ('93%', '93x', '93%')
# ('Pneumonia Patients Assessed and Given Influenza Vaccination', 'Pneumonix Pxtients Assessed xnd Given Influenzx Vxccinxtion', 'Pneumonia Patients Assessed and Given Influenza Vaccination')
# ('Acute Care Hospitals', 'Acuxe Care Hospixals', 'Acute Care Hospitals')
# ('CHEROKEE', 'CHxROKxx', 'CHEROKEE')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('3342882100', '3342xx2100', '3342882100')
# ('MONTGOMERY', 'MONTxOMERY', 'MONTGOMERY')
# ('Voluntary non-profit - Church', 'Volxntary non-profit - Chxrch', 'Voluntary non-profit - Church')
# ('MONTGOMERY', 'MONxGOMERY', 'MONTGOMERY')
# ('BAPTIST MEDICAL CENTER SOUTH', 'BAPTIST MEDICAL CExTER SOUTH', 'BAPTIST MEDICAL CENTER SOUTH')
# ('Acute Care Hospitals', 'Acute Care Hosxitals', 'Acute Care Hospitals')
# ('Pneumonia Patients Assessed and Given Influenza Vaccination', 'Pxeumoxia Patiexts Assessed axd Givex Ixfluexza Vaccixatiox', 'Pneumonia Patients Assessed and Given Influenza Vaccination')
# ('87 patients', '87 patientx', '87 patients')
# ('Yes', 'Yex', 'Yes')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('MONTGOMERY', 'MONTGOMExY', 'MONTGOMERY')
# ('Heart Attack Patients Given Aspirin at Arrival', 'Hexrt Attxck Pxtients Given Aspirin xt Arrivxl', 'Heart Attack Patients Given Aspirin at Arrival')
# ('Heart Attack Patients Given Beta Blocker at Discharge', 'Heaxt Attack Patients Given Beta Blockex at Dischaxge', 'Heart Attack Patients Given Beta Blocker at Discharge')
# ('3342938000', '3342938xxx', '3342938000')
# ('MONTGOMERY', 'MONxGOMERY', 'MONTGOMERY')
# ('74 patients', '74 patxents', '74 patients')
# ('Pneumonia', 'Pxeumoxia', 'Pneumonia')
# ('AL_PN-5C', 'AL_PN-5x', 'AL_PN-5C')
# ('JACKSON HOSPITAL & CLINIC INC', 'JAxKSON HOSPITAL & xLINIx INx', 'JACKSON HOSPITAL & CLINIC INC')
# ('3342938000', '33x2938000', '3342938000')
# ('3342938000', '3342938xxx', '3342938000')
# ('all heart surgery patients whose blood sugar (blood glucose) is kept under good control in the days right after surgery', 'allxheartxsurgeryxpatientsxwhosexbloodxsugarx(bloodxglucose)xisxkeptxunderxgoodxcontrolxinxthexdaysxrightxafterxsurgery', 'all heart surgery patients whose blood sugar (blood glucose) is kept under good control in the days right after surgery')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('Yes', 'xes', 'Yes')
# ('AL_SCIP-VTE-1', 'AL_SCIPxVTEx1', 'AL_SCIP-VTE-1')
# ('3347561400', '334x561400', '3347561400')
# ('Voluntary non-profit - Other', 'Voluntary non-profit - Otxer', 'Voluntary non-profit - Other')
# ('VALLEY', 'VALLEx', 'VALLEY')
# ('CHAMBERS', 'xHAMBERS', 'CHAMBERS')
# ('Yes', 'xes', 'Yes')
# ('Yes', 'xes', 'Yes')
# ('Acute Care Hospitals', 'Acuxe Care Hospixals', 'Acute Care Hospitals')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('172 patients', '172 patxents', '172 patients')
# ('VALLEY', 'VxLLEY', 'VALLEY')
# ('CHAMBERS', 'CHAxBERS', 'CHAMBERS')
# ('3348972257', '33x8972257', '3348972257')
# ('Heart Failure', 'Heart Faixure', 'Heart Failure')
# ('ELBA', 'ExBA', 'ELBA')
# ('COFFEE', 'COFFxx', 'COFFEE')
# ('Surgical Infection Prevention', 'Surgical Ixfectiox Prevextiox', 'Surgical Infection Prevention')
# ('all heart surgery patients whose blood sugar (blood glucose) is kept under good control in the days right after surgery', 'all heaxt suxgexy patients whose blood sugax (blood glucose) is kept undex good contxol in the days xight aftex suxgexy', 'all heart surgery patients whose blood sugar (blood glucose) is kept under good control in the days right after surgery')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('Yes', 'Yex', 'Yes')
# ('Pneumonia', 'Pneumonxa', 'Pneumonia')
# ('Acute Care Hospitals', 'Acuxe Care Hospixals', 'Acute Care Hospitals')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('SCIP-VTE-1', 'SCIP-VTx-1', 'SCIP-VTE-1')
# ('Heart Failure Patients Given ACE Inhibitor or ARB for Left Ventricular Systolic Dysfunction (LVSD)', 'Heart Failure Patients Given ACE Inhibitor or ARB for Left xentricular Systolic Dysfunction (LxSD)', 'Heart Failure Patients Given ACE Inhibitor or ARB for Left Ventricular Systolic Dysfunction (LVSD)')
# ('Heart Failure Patients Given Smoking Cessation Advice/Counseling', 'Heart Faxlure Patxents Gxven Smokxng Cessatxon Advxce/Counselxng', 'Heart Failure Patients Given Smoking Cessation Advice/Counseling')
# ('209 NORTH MAIN STREET', '209 xORTH MAIx STREET', '209 NORTH MAIN STREET')
# ('WEDOWEE', 'WxDOWxx', 'WEDOWEE')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('2059344011', '20593xx011', '2059344011')
# ('87 patients', '87 paxienxs', '87 patients')
# ('JEFFERSON', 'JxFFxRSON', 'JEFFERSON')
# ('Heart Attack Patients Given PCI Within 90 Minutes Of Arrival', 'HeartxAttackxPatientsxGivenxPCIxWithinx90xMinutesxOfxArrival', 'Heart Attack Patients Given PCI Within 90 Minutes Of Arrival')
# ('618 patients', '618 xatients', '618 patients')
# ('Yes', 'Yex', 'Yes')
# ('HF-4', 'HFx4', 'HF-4')
# ('Pneumonia', 'xneumonia', 'Pneumonia')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('JEFFERSON', 'JExxERSON', 'JEFFERSON')
# ('BIRMINGHAM', 'BIRMINxHAM', 'BIRMINGHAM')
# ('ELMORE', 'ELMOxE', 'ELMORE')
# ('Acute Care Hospitals', 'Acute Cxre Hospitxls', 'Acute Care Hospitals')
# ('Heart Attack', 'Heart Attaxk', 'Heart Attack')
# ('TALLASSEE', 'TALLAxxEE', 'TALLASSEE')
# ('COMMUNITY HOSPITAL INC', 'COMMUNITx HOSPITAL INC', 'COMMUNITY HOSPITAL INC')
# ('ELMORE', 'ELxORE', 'ELMORE')
# ('Heart Failure', 'Hexrt Fxilure', 'Heart Failure')
# ('3342836541', '334x836541', '3342836541')
# ('Acute Care Hospitals', 'AcutexCarexHospitals', 'Acute Care Hospitals')
# ('Pneumonia Patients Given Initial Antibiotic(s) within 6 Hours After Arrival', 'Pxeumoxia Patiexts Givex Ixitial Axtibiotic(s) withix 6 Hours After Arrival', 'Pneumonia Patients Given Initial Antibiotic(s) within 6 Hours After Arrival')
# ('Pneumonia Patients Given the Most Appropriate Initial Antibiotic(s)', 'Pxeumoxia Patiexts Givex the Most Appropriate Ixitial Axtibiotic(s)', 'Pneumonia Patients Given the Most Appropriate Initial Antibiotic(s)')
# ('COMMUNITY HOSPITAL INC', 'COMMUNIxY HOSPIxAL INC', 'COMMUNITY HOSPITAL INC')
# ('36078', '36x78', '36078')
# ('Surgical Infection Prevention', 'Surgical Infection xrevention', 'Surgical Infection Prevention')
# ('3342836541', '33x28365x1', '3342836541')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery paxienxs needing hair removed from xhe surgical area before surgery who had hair removed using a safer mexhod (elecxric clippers or hair removal cream C nox a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('Heart Attack', 'HeartxAttack', 'Heart Attack')
# ('AMI-3', 'AMx-3', 'AMI-3')
# ('AL_AMI-7A', 'AL_AMx-7A', 'AL_AMI-7A')
# ('CULLMAN', 'CxLLMAN', 'CULLMAN')
# ('Acute Care Hospitals', 'AcutexCarexHospitals', 'Acute Care Hospitals')
# ('CULLMAN REGIONAL MEDICAL CENTER', 'CULLMxN REGIONxL MEDICxL CENTER', 'CULLMAN REGIONAL MEDICAL CENTER')
# ('CULLMAN', 'CxLLMAN', 'CULLMAN')
# ('Surgical Infection Prevention', 'Suxgical Infection Pxevention', 'Surgical Infection Prevention')
# ('SCIP-INF-2', 'SCIx-INF-2', 'SCIP-INF-2')
# ('1912 ALABAMA HIGHWAY 157', '1912xALABAMAxHIGHWAYx157', '1912 ALABAMA HIGHWAY 157')
# ('CULLMAN', 'CUxxMAN', 'CULLMAN')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('Proprietary', 'Prxprietary', 'Proprietary')
# ('36420', '3642x', '36420')
# ('3342228466', '334xxx8466', '3342228466')
# ('COVINGTON', 'COxINGTON', 'COVINGTON')
# ('ANDALUSIA', 'ANDALUxIA', 'ANDALUSIA')
# ('ANDALUSIA REGIONAL HOSPITAL', 'ANDAxUSIA REGIONAx HOSPITAx', 'ANDALUSIA REGIONAL HOSPITAL')
# ('3342228466', '33422284xx', '3342228466')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('AL_SCIP-VTE-1', 'AL_SCIx-VTE-1', 'AL_SCIP-VTE-1')
# ('ANDALUSIA REGIONAL HOSPITAL', 'ANDALUxIA REGIONAL HOxPITAL', 'ANDALUSIA REGIONAL HOSPITAL')
# ('301 EAST 18TH ST', '301 EAST 1xTH ST', '301 EAST 18TH ST')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('ANNISTON', 'ANNxSTON', 'ANNISTON')
# ('Acute Care Hospitals', 'AcutexCarexHospitals', 'Acute Care Hospitals')
# ('Heart Attack', 'Heart Attaxk', 'Heart Attack')
# ('Acute Care Hospitals', 'Acute Care Hospitaxs', 'Acute Care Hospitals')
# ('Government - Hospital District or Authority', 'Goverxmext - Hospital District or Authority', 'Government - Hospital District or Authority')
# ('MADISON', 'MADISxN', 'MADISON')
# ('Heart Failure Patients Given an Evaluation of Left Ventricular Systolic (LVS) Function', 'Heaxt Failuxe Patients Given an Evaluation of Left Ventxiculax Systolic (LVS) Function', 'Heart Failure Patients Given an Evaluation of Left Ventricular Systolic (LVS) Function')
# ('MADISON', 'MADISOx', 'MADISON')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('Heart Attack Patients Given Aspirin at Arrival', 'Heart Attack Patxents Gxven Aspxrxn at Arrxval', 'Heart Attack Patients Given Aspirin at Arrival')
# ('Yes', 'xes', 'Yes')
# ('Acute Care Hospitals', 'Axute Care Hospitals', 'Acute Care Hospitals')
# ('Pneumonia Patients Given Initial Antibiotic(s) within 6 Hours After Arrival', 'Pneumonix Pxtients Given Initixl Antibiotic(s) within 6 Hours After Arrivxl', 'Pneumonia Patients Given Initial Antibiotic(s) within 6 Hours After Arrival')
# ('GADSDEN', 'GxDSDEN', 'GADSDEN')
# ('2564944000', '2564944xxx', '2564944000')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('PN-6', 'PNx6', 'PN-6')
# ('AL_PN-6', 'AL_PNx6', 'AL_PN-6')
# ('4 patients', '4 patiexts', '4 patients')
# ('Voluntary non-profit - Private', 'Voluntaxy non-pxofit - Pxivate', 'Voluntary non-profit - Private')
# ('Acute Care Hospitals', 'Acute Caxe Hospitals', 'Acute Care Hospitals')
# ('1010 LAY DAM ROAD', 'x0x0 LAY DAM ROAD', '1010 LAY DAM ROAD')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('Surgical Infection Prevention', 'Surgical Infxction Prxvxntion', 'Surgical Infection Prevention')
# ('1256 MILITARY STREET SOUTH', '1256 MILITARY STREET SxUTH', '1256 MILITARY STREET SOUTH')
# ('2059216200', '20x9216200', '2059216200')
# ('Voluntary non-profit - Private', 'Voluxtary xox-profit - Private', 'Voluntary non-profit - Private')
# ('Surgical Infection Prevention', 'Surgical Ixfectiox Prevextiox', 'Surgical Infection Prevention')
# ('Voluntary non-profit - Private', 'Voluntaxy non-pxofit - Pxivate', 'Voluntary non-profit - Private')
# ('15 patients', '15 patiexts', '15 patients')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('Acute Care Hospitals', 'Acute Care Hoxpitalx', 'Acute Care Hospitals')
# ('2059325966', 'x0593x5966', '2059325966')
# ('2059325966', 'x0593x5966', '2059325966')
# ('Yes', 'Yex', 'Yes')
# ('Pneumonia Patients Assessed and Given Influenza Vaccination', 'Pneumonia Patients Assessed and Given Influenza Vaxxination', 'Pneumonia Patients Assessed and Given Influenza Vaccination')
# ('FAYETTE', 'FAxETTE', 'FAYETTE')
# ('FAYETTE', 'FAYExxE', 'FAYETTE')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('Acute Care Hospitals', 'AcutexCarexHospitals', 'Acute Care Hospitals')
# ('Children Who Received Reliever Medication While Hospitalized for Asthma', 'ChildrenxWhoxReceivedxRelieverxMedicationxWhilexHospitalizedxforxAsthma', 'Children Who Received Reliever Medication While Hospitalized for Asthma')
# ('RIVERVIEW REGIONAL MEDICAL CENTER', 'RIVxRVIxW RxGIONAL MxDICAL CxNTxR', 'RIVERVIEW REGIONAL MEDICAL CENTER')
# ('126 patients', '126 patxents', '126 patients')
# ('Heart Failure Patients Given Smoking Cessation Advice/Counseling', 'Hearx Failure Paxienxs Given Smoking Cessaxion Advice/Counseling', 'Heart Failure Patients Given Smoking Cessation Advice/Counseling')
# ('2565435200', 'x565435x00', '2565435200')
# ('ETOWAH', 'ETOWxH', 'ETOWAH')
# ('Yes', 'Yex', 'Yes')
# ('RIVERVIEW REGIONAL MEDICAL CENTER', 'xIVExVIEW xEGIONAL MEDICAL CENTEx', 'RIVERVIEW REGIONAL MEDICAL CENTER')
# ('RIVERVIEW REGIONAL MEDICAL CENTER', 'RIVERVIEW RExIONAL MEDICAL CENTER', 'RIVERVIEW REGIONAL MEDICAL CENTER')
# ('Acute Care Hospitals', 'Acuxe Care Hospixals', 'Acute Care Hospitals')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('515 MIRANDA ST', '515 MIRANxA ST', '515 MIRANDA ST')
# ('GEORGIANA HOSPITAL', 'GEORGIAxA HOSPITAL', 'GEORGIANA HOSPITAL')
# ('BUTLER', 'BUTxER', 'BUTLER')
# ('515 MIRANDA ST', '515 MIRxNDx ST', '515 MIRANDA ST')
# ('GEORGIANA', 'GEOxGIANA', 'GEORGIANA')
# ('Acute Care Hospitals', 'Acute Care Hosxitals', 'Acute Care Hospitals')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('Heart Attack', 'Hexrt Attxck', 'Heart Attack')
# ('400 N EDWARDS STREET', '400xNxEDWARDSxSTREET', '400 N EDWARDS STREET')
# ('Acute Care Hospitals', 'Acute xare Hospitals', 'Acute Care Hospitals')
# ('ENTERPRISE', 'ENTERPRxSE', 'ENTERPRISE')
# ('MEDICAL CENTER ENTERPRISE', 'MEDxCAL CENTER ENTERPRxSE', 'MEDICAL CENTER ENTERPRISE')
# ('Acute Care Hospitals', 'AcutexCarexHospitals', 'Acute Care Hospitals')
# ('COFFEE', 'CxFFEE', 'COFFEE')
# ('ENTERPRISE', 'xNTxRPRISx', 'ENTERPRISE')
# ('27 patients', '27 paxienxs', '27 patients')
# ('Surgical Infection Prevention', 'Surgical xnfection Prevention', 'Surgical Infection Prevention')
# ('Acute Care Hospitals', 'AcutexCarexHospitals', 'Acute Care Hospitals')
# ('surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream C not a razor)', 'surgery patients needing hair removed from the surgical area before surgery who had hair removed using a safer method (electric clippers or hair removal cream �C not a razor)')
# ('ONEONTA', 'ONxONTA', 'ONEONTA')
# ('150 GILBREATH DRIVE', '150 GILxREATH DRIVE', '150 GILBREATH DRIVE')
# ('ST VINCENTS BLOUNT', 'ST VINCENTS BxOUNT', 'ST VINCENTS BLOUNT')
# ('surgery patients who were taking heart drugs called beta blockers before coming to the hospital who were kept on the beta blockers during the period just before and after their surgery', 'surgery pxtients who were txking hexrt drugs cxlled betx blockers before coming to the hospitxl who were kept on the betx blockers during the period just before xnd xfter their surgery', 'surgery patients who were taking heart drugs called beta blockers before coming to the hospital who were kept on the beta blockers during the period just before and after their surgery')

# %%
falsely_predicted[1]
# Out:
# ('588 patients', '3x patients', '37 patients')

# %%
model_hosp.most_similar('3595x')
# Out:
# [('35957', 0.9884520769119263),
#  ('35976', 0.9203376770019531),
#  ('BOAZ', 0.8603140115737915),
#  ('2565938310', 0.8538941144943237),
#  ('MARSHALL', 0.8307958841323853),
#  ('2505 U S HIGHWAY 431 NORTH', 0.7380251884460449),
#  ('2565718000', 0.7368029356002808),
#  ('35960', 0.6880041360855103),
#  ('MARSHALL MEDICAL CENTER NORTH', 0.6846861243247986),
#  ('35903', 0.6814932823181152)]
