# %%
import pandas as pd
import numpy as np
import random
import string

# %%
df = pd.read_csv('final.csv', encoding='utf8')

# %%
df.head()
# Out:
#    ProviderNumber                       HospitalName  \
# 0         10164.0             FAYETTE MEDICAL CENTER
# 1         10046.0  RIVERVIEW REGIONAL MEDICAL CENTER
# 2         10010.0      MARSHALL MEDICAL CENTER NORTH
# 3         10018.0   CALLAHAN EYE FOUNDATION HOSPITAL
# 4         10034.0             COMMUNITY HOSPITAL INC
#
#                    Address1          City State  ZipCode CountyName  \
# 0  1653 TEMPLE AVENUE NORTH       FAYETTE    AL  35555.0    FAYETTE
# 1    600 SOUTH THIRD STREET       GADSDEN    AL  35968.0     ETOWAH
# 2   8000 ALABAMA HIGHWAY 69  GUNTERSVILLE    AL  35976.0   MARSHALL
# 3      1720 UNIVERSITY BLVD    BIRMINGHAM    AL  35233.0  JEFFERSON
# 4       805 FRIENDSHIP ROAD     TALLASSEE    AL  36854.0     ELMORE
#
#     PhoneNumber          HospitalType  label
# 0  2.059326e+09  Acute Care Hospitals    0.0
# 1  2.565435e+09  Acute Care Hospitals    0.0
# 2  2.565718e+09  Acute Care Hospitals    1.0
# 3  2.053258e+09  Acute Care Hospitals    1.0
# 4  3.342837e+09  Acute Care Hospitals    0.0

# %%
len(df)
# Out:
# 2000

# %%
dfClean = df[df['label'] == 1]

# %%
len(dfClean)
# Out:
# 1000

# %%
dfClean.head()
# Out:
#     ProviderNumber                      HospitalName  \
# 2          10010.0     MARSHALL MEDICAL CENTER NORTH
# 3          10018.0  CALLAHAN EYE FOUNDATION HOSPITAL
# 7          10005.0     MARSHALL MEDICAL CENTER SOUTH
# 10         10025.0      G H LANIER MEMORIAL HOSPITAL
# 11         10045.0            FAYETTE MEDICAL CENTER
#
#                       Address1          City State  ZipCode CountyName  \
# 2      8000 ALABAMA HIGHWAY 69  GUNTERSVILLE    AL  35976.0   MARSHALL
# 3         1720 UNIVERSITY BLVD    BIRMINGHAM    AL  35233.0  JEFFERSON
# 7   2505 U S HIGHWAY 431 NORTH          BOAZ    AL  35957.0   MARSHALL
# 10                4800 48TH ST        VALLEY    AL  36854.0   CHAMBERS
# 11    1653 TEMPLE AVENUE NORTH       FAYETTE    AL  35555.0    FAYETTE
#
#      PhoneNumber          HospitalType  label
# 2   2.565718e+09  Acute Care Hospitals    1.0
# 3   2.053258e+09  Acute Care Hospitals    1.0
# 7   2.565938e+09  Acute Care Hospitals    1.0
# 10  3.347561e+09  Acute Care Hospitals    1.0
# 11  2.059326e+09  Acute Care Hospitals    1.0

# %%
dfClean.to_csv("CleanHospitalDataset.csv", encoding='utf8',index=False)

# %% [markdown]
# ### Adding spelling mistakes

# %%
dfSpell = dfClean.sample(frac=0.1)

# %%
len(dfSpell)
# Out:
# 100

# %%
columns = ["HospitalName", "Address1", "City", "CountyName"]

# %%
def modifyValue(value):
    wordList = list(value)
    randomPosition = random.randint(0, len(value) - 1)
    currentChar = wordList[randomPosition]
    
    lowercase = set(string.ascii_lowercase)
    uppercase = set(string.ascii_uppercase)
    digits = set(string.digits)
    
    while currentChar.isspace() is True:
        randomPosition = random.randint(0, len(value) - 1)
        currentChar = wordList[randomPosition]
    
    if currentChar.isalpha():
        if currentChar.islower():
            char = random.choice(list(lowercase - set(currentChar)))
        else:
            char = random.choice(list(uppercase - set(currentChar)))
    else:
        char = random.choice(list(digits - set(currentChar)))
    
    wordList[randomPosition] = str(char)
    return ''.join(wordList)

# %%
for index, row in dfSpell.iterrows():
    column = random.choice(columns)
    value = row[column]
    modifiedValue = modifyValue(value)
    dfSpell.at[index, column] = modifiedValue
    dfSpell.at[index, 'label'] = 0

# %%
dfSpell.tail()
# Out:
#       ProviderNumber                    HospitalName                 Address1  \
# 1747         10010.0   MARSHABL MEDICAL CENTER NORTH  8000 ALABAMA HIGHWAY 69
# 1044         10164.0     COOSA VALLEY MEDICAL CENTER         315 W HICKORY ST
# 1811         10038.0  STRINGFELLOW MEMORIAL HOSPIBAL         301 EAST 18TH ST
# 906          20017.0        ALASKA REGIONAL HOSPITAL         2801 DEBARR ROAD
# 1188         10047.0              GEORGIANA HOSPITAL           515 MIRANDA ST
#
#               City State  ZipCode CountyName   PhoneNumber  \
# 1747  GUNTERSVILLE    AL  35976.0   MARSHALL  2.565718e+09
# 1044     SYLACAUGC    AL  35150.0  TALLADEGA  2.562495e+09
# 1811      ANNISTON    AL  36201.0    CALHOUN  2.562359e+09
# 906      ANCKORAGE    AK  99508.0  ANCHORAGE  9.072761e+09
# 1188     GEORGIANA    AL  36033.0     ZUTLER  3.343762e+09
#
#               HospitalType  label
# 1747  Acute Care Hospitals    0.0
# 1044  Acute Care Hospitals    0.0
# 1811  Acute Care Hospitals    0.0
# 906   Acute Care Hospitals    0.0
# 1188  Acute Care Hospitals    0.0

# %%
df = pd.concat([df, dfSpell])

# %%
len(df)
# Out:
# 2100

# %%
df.tail()
# Out:
#       ProviderNumber                    HospitalName                 Address1  \
# 1747         10010.0   MARSHABL MEDICAL CENTER NORTH  8000 ALABAMA HIGHWAY 69
# 1044         10164.0     COOSA VALLEY MEDICAL CENTER         315 W HICKORY ST
# 1811         10038.0  STRINGFELLOW MEMORIAL HOSPIBAL         301 EAST 18TH ST
# 906          20017.0        ALASKA REGIONAL HOSPITAL         2801 DEBARR ROAD
# 1188         10047.0              GEORGIANA HOSPITAL           515 MIRANDA ST
#
#               City State  ZipCode CountyName   PhoneNumber  \
# 1747  GUNTERSVILLE    AL  35976.0   MARSHALL  2.565718e+09
# 1044     SYLACAUGC    AL  35150.0  TALLADEGA  2.562495e+09
# 1811      ANNISTON    AL  36201.0    CALHOUN  2.562359e+09
# 906      ANCKORAGE    AK  99508.0  ANCHORAGE  9.072761e+09
# 1188     GEORGIANA    AL  36033.0     ZUTLER  3.343762e+09
#
#               HospitalType  label
# 1747  Acute Care Hospitals    0.0
# 1044  Acute Care Hospitals    0.0
# 1811  Acute Care Hospitals    0.0
# 906   Acute Care Hospitals    0.0
# 1188  Acute Care Hospitals    0.0

# %%
from sklearn.utils import shuffle
df = shuffle(df)

# %%
df.tail()
# Out:
#       ProviderNumber                    HospitalName              Address1  \
# 997          10049.0       MEDICAL CENTER ENTERPRISE  400 N EDWARDS STREET
# 1415         10034.0          COMMUNITY HOSPITAL INC   805 FRIENDSHIP ROAD
# 235          10007.0        MIZELL MEMORIAL HOSPITAL         702 N MAIN ST
# 924          10024.0   JACKSON HOSPITAL & CLINIC INC      1725 PINE STREET
# 881          10044.0  STRINGFELLOW MEMORIAL HOSPITAL      301 EAST 18TH ST
#
#             City State  ZipCode  CountyName   PhoneNumber  \
# 997   ENTERPRISE    AL  36330.0      COFFEE  3.343471e+09
# 1415      CENTRE    AL  36078.0      ELMORE  3.342837e+09
# 235          OPP    AL  36467.0     AUTAUGA  3.344934e+09
# 924   MONTGOMERY    AL  36106.0  MONTGOMERY  3.342938e+09
# 881          NaN   NaN  36201.0     CALHOUN  2.562359e+09
#
#               HospitalType  label
# 997   Acute Care Hospitals    1.0
# 1415  Acute Care Hospitals    0.0
# 235   Acute Care Hospitals    0.0
# 924   Acute Care Hospitals    0.0
# 881   Acute Care Hospitals    0.0

# %%
df.to_csv('DirtyHospitalDataset.csv', encoding='utf8', index=False)
